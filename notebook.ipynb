# %%
print(maps[0].points[0])
# Out:
# Point(id=00bd6b72-1eb3-426e-9d6a-a080fc29fdf2, map=33b196a9-a51c-4695-b049-64f95bb33daa, cluster=3500b399-476d-492f-a3a9-84c70942618b, data_row=<__main__.DataRow object at 0x7f41e6594ee0>, date=None, color=None, title=2023 Dodge Charger SXT | Dodge Charger SXT Overview, summary=, keywords=[], embedding=..., raw_embedding2=...)
